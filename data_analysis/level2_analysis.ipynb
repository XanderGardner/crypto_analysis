# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

df = pd.read_csv("../processed_data/btc_level2_processed_data.csv")
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'time', 'close', 'volume',
#        'close_15_min_future_percent_change',
#        'close_10_min_future_percent_change',
#        'close_5_min_future_percent_change', 'volume_1_min_past_percent_change',
#        'friction_up', 'friction_down', 'friction_difference'],
#       dtype='object')

# %%
df.corr()
# Out:
# /var/folders/yc/n6lh7krx6p3b0zmdngvdb48c0000gn/T/ipykernel_31435/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                     Unnamed: 0     close    volume  \
# Unnamed: 0                            1.000000  0.829736 -0.306361
# close                                 0.829736  1.000000 -0.132258
# volume                               -0.306361 -0.132258  1.000000
# close_15_min_future_percent_change   -0.233970 -0.240321  0.175688
# close_10_min_future_percent_change   -0.193484 -0.196980  0.176923
# close_5_min_future_percent_change    -0.132375 -0.136393  0.151139
# volume_1_min_past_percent_change      0.100590  0.043927  0.040941
# friction_up                           0.169900  0.462389  0.083814
# friction_down                         0.047866 -0.022548 -0.135572
# friction_difference                   0.118038  0.398494  0.138698
#
#                                     close_15_min_future_percent_change  \
# Unnamed: 0                                                   -0.233970
# close                                                        -0.240321
# volume                                                        0.175688
# close_15_min_future_percent_change                            1.000000
# close_10_min_future_percent_change                            0.821594
# close_5_min_future_percent_change                             0.596297
# volume_1_min_past_percent_change                             -0.019886
# friction_up                                                  -0.121542
# friction_down                                                 0.024012
# friction_difference                                          -0.113907
#
#                                     close_10_min_future_percent_change  \
# Unnamed: 0                                                   -0.193484
# close                                                        -0.196980
# volume                                                        0.176923
# close_15_min_future_percent_change                            0.821594
# close_10_min_future_percent_change                            1.000000
# close_5_min_future_percent_change                             0.703646
# volume_1_min_past_percent_change                             -0.008066
# friction_up                                                  -0.093092
# friction_down                                                 0.001083
# friction_difference                                          -0.078613
#
#                                     close_5_min_future_percent_change  \
# Unnamed: 0                                                  -0.132375
# close                                                       -0.136393
# volume                                                       0.151139
# close_15_min_future_percent_change                           0.596297
# close_10_min_future_percent_change                           0.703646
# close_5_min_future_percent_change                            1.000000
# volume_1_min_past_percent_change                            -0.029954
# friction_up                                                 -0.048937
# friction_down                                                0.001448
# friction_difference                                         -0.041729
#
#                                     volume_1_min_past_percent_change  \
# Unnamed: 0                                                  0.100590
# close                                                       0.043927
# volume                                                      0.040941
# close_15_min_future_percent_change                         -0.019886
# close_10_min_future_percent_change                         -0.008066
# close_5_min_future_percent_change                          -0.029954
# volume_1_min_past_percent_change                            1.000000
# friction_up                                                -0.028260
# friction_down                                               0.028415
# friction_difference                                        -0.034357
#
#                                     friction_up  friction_down  \
# Unnamed: 0                             0.169900       0.047866
# close                                  0.462389      -0.022548
# volume                                 0.083814      -0.135572
# close_15_min_future_percent_change    -0.121542       0.024012
# close_10_min_future_percent_change    -0.093092       0.001083
# close_5_min_future_percent_change     -0.048937       0.001448
# volume_1_min_past_percent_change      -0.028260       0.028415
# friction_up                            1.000000      -0.051537
# friction_down                         -0.051537       1.000000
# friction_difference                    0.863217      -0.548650
#
#                                     friction_difference
# Unnamed: 0                                     0.118038
# close                                          0.398494
# volume                                         0.138698
# close_15_min_future_percent_change            -0.113907
# close_10_min_future_percent_change            -0.078613
# close_5_min_future_percent_change             -0.041729
# volume_1_min_past_percent_change              -0.034357
# friction_up                                    0.863217
# friction_down                                 -0.548650
# friction_difference                            1.000000

# %%
df.plot(kind="scatter", x="friction_difference", y="close_15_min_future_percent_change", c="volume_1_min_past_percent_change")
# Out:
# <AxesSubplot: xlabel='friction_difference', ylabel='close_15_min_future_percent_change'>
