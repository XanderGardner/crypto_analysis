# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

df = pd.read_csv("../processed_data/btc_level2_processed_data.csv")
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'time', 'close', 'volume',
#        'close_15_min_future_percent_change',
#        'close_10_min_future_percent_change',
#        'close_5_min_future_percent_change', 'volume_1_min_past_percent_change',
#        'friction_up', 'friction_down', 'friction_difference'],
#       dtype='object')

# %%
df.corr()
# Out:
# /var/folders/yc/n6lh7krx6p3b0zmdngvdb48c0000gn/T/ipykernel_16072/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                     Unnamed: 0     close    volume  \
# Unnamed: 0                            1.000000  0.713051 -0.184215
# close                                 0.713051  1.000000 -0.042327
# volume                               -0.184215 -0.042327  1.000000
# close_15_min_future_percent_change   -0.008217 -0.216045  0.100683
# close_10_min_future_percent_change   -0.010459 -0.176316  0.115562
# close_5_min_future_percent_change    -0.023214 -0.145121  0.083541
# volume_1_min_past_percent_change      0.064802  0.003833  0.081109
# friction_up                          -0.462215 -0.241914  0.104906
# ...

# %%
df.plot(kind="scatter", x="friction_difference", y="close_15_min_future_percent_change", c="volume_1_min_past_percent_change")
# Out:
# <AxesSubplot: xlabel='friction_difference', ylabel='close_15_min_future_percent_change'>
