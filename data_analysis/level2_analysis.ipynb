# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

df = pd.read_csv("../processed_data/level2_processed_data.csv")
display(pd.DataFrame(df.columns))
# Out:
#                                           0
# 0                                Unnamed: 0
# 1                                      time
# 2                                 btc_close
# 3                                 eth_close
# 4                                doge_close
# 5                                btc_volume
# 6                                eth_volume
# 7                               doge_volume
# 8                    btc_friction_diff_0.25
# 9                     btc_friction_diff_0.5
# 10                   btc_friction_diff_0.75
# 11                    btc_friction_diff_1.0
# 12                   btc_friction_diff_1.25
# 13                    btc_friction_diff_1.5
# 14                   btc_friction_diff_1.75
# 15                    btc_friction_diff_2.0
# 16                   eth_friction_diff_0.25
# 17                    eth_friction_diff_0.5
# 18                   eth_friction_diff_0.75
# 19                    eth_friction_diff_1.0
# ...

# %%
df.corr().to_csv("corrs.csv")
# Out:
# /var/folders/yc/n6lh7krx6p3b0zmdngvdb48c0000gn/T/ipykernel_31435/2287935496.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr().to_csv("corrs.csv")

# %%
crypto = "eth"
df.plot(kind="scatter", x=f"{crypto}_friction_diff_1.0", y=f"{crypto}_close_15_min_future_percent_change", c=f"{crypto}_volume_1_min_past_percent_change")
# Out:
# <AxesSubplot: xlabel='eth_friction_diff_1.0', ylabel='eth_close_15_min_future_percent_change'>

# %%
crypto = "eth"
df.plot(kind="scatter", x=f"btc_close_15_min_past_percent_change", y=f"doge_close_15_min_future_percent_change", c=f"eth_close_15_min_past_percent_change")
# Out:
# <AxesSubplot: xlabel='btc_close_15_min_past_percent_change', ylabel='doge_close_15_min_future_percent_change'>
