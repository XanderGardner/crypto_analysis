# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt

df = pd.read_csv("../processed_data/eth_level1_processed_data.csv")
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Date', 'Price', 'Market Cap', 'Volume',
#        'Active Addresses', 'Daily Transactions', 'Twitter Followers',
#        'Weekly Commits Core', 'Weekly Commits Sub', 'Weekly Devs Core',
#        'Weekly Devs Sub', 'Total Value Locked', 'Price Bitcoin',
#        'Price 1 Day Past Percent Change', 'Price 7 Day Past Percent Change',
#        'Price 14 Day Past Percent Change', 'Price 30 Day Past Percent Change',
#        'Market Cap 1 Day Past Percent Change',
#        'Market Cap 7 Day Past Percent Change',
#        'Market Cap 14 Day Past Percent Change',
#        'Market Cap 30 Day Past Percent Change',
#        'Volume 1 Day Past Percent Change', 'Volume 7 Day Past Percent Change',
#        'Volume 14 Day Past Percent Change',
#        'Volume 30 Day Past Percent Change',
#        'Active Addresses 1 Day Past Percent Change',
#        'Active Addresses 7 Day Past Percent Change',
#        'Active Addresses 14 Day Past Percent Change',
# ...

# %% [markdown]
# # Market Cap

# %%
df.plot(kind="scatter", x="Market Cap 1 Day Past Percent Change", y="Volume", c="Price 1 Day Future Percent Change")
# Out:
# <AxesSubplot: xlabel='Market Cap 1 Day Past Percent Change', ylabel='Volume'>

# %% [markdown]
# # Volume

# %%
df.plot(kind="scatter", x="Volume", y="Price 1 Day Future Percent Change")
# Out:
# <AxesSubplot: xlabel='Volume', ylabel='Price 1 Day Future Percent Change'>

# %% [markdown]
# # Active Addresses

# %%
df.plot(kind="scatter", x="Active Addresses 1 Day Past Percent Change", y="Price 1 Day Future Percent Change")
# Out:
# <AxesSubplot: xlabel='Active Addresses 1 Day Past Percent Change', ylabel='Price 1 Day Future Percent Change'>

# %% [markdown]
# # Daily Transactions

# %%
df.plot(kind="scatter", x="Daily Transactions 1 Day Past Percent Change", y="Price 1 Day Future Percent Change")
# Out:
# <AxesSubplot: xlabel='Daily Transactions 1 Day Past Percent Change', ylabel='Price 1 Day Future Percent Change'>

# %% [markdown]
# # Twitter Followers

# %%
df.plot(kind="scatter", x="Twitter Followers 1 Day Past Percent Change", y="Price 1 Day Future Percent Change", c="Volume")
# Out:
# <AxesSubplot: xlabel='Twitter Followers 1 Day Past Percent Change', ylabel='Price 1 Day Future Percent Change'>

# %% [markdown]
# # Weekly Commits Core

# %%
df.plot(kind="scatter", x="Weekly Commits Core 7 Day Past Percent Change", y="Price 1 Day Future Percent Change", c="Volume")
# Out:
# <AxesSubplot: xlabel='Weekly Commits Core 7 Day Past Percent Change', ylabel='Price 1 Day Future Percent Change'>

# %% [markdown]
# # Total Value Locked

# %%
df.plot(kind="scatter", x="Total Value Locked 7 Day Past Percent Change", y="Price 1 Day Future Percent Change", c="Volume", xlim=[-1,1])
# Out:
# <AxesSubplot: xlabel='Total Value Locked 7 Day Past Percent Change', ylabel='Price 1 Day Future Percent Change'>

# %% [markdown]
# # Price Bitcoin

# %%
df.plot(kind="scatter", x="Price Bitcoin", y="Price 1 Day Future Percent Change", c="Volume")
# Out:
# <AxesSubplot: xlabel='Price Bitcoin', ylabel='Price 1 Day Future Percent Change'>
